# %% [markdown]
# 총 2개의 TODO가 존재합니다.
#
# 위에서부터 차례대로 셀을 실행하면서, TODO가 존재하는 셀을 발견하면 적당한 값을 채워주세요.
# 정답은 없습니다!
#
# 모두 실행시킨 후에 ipynb 파일을 본인의 github에 올려주시면 됩니다.
#
# 수고하셨습니다😆

# %%
#!pip install konlpy

# %%
import pandas as pd
import matplotlib.pyplot as plt
import urllib.request
from gensim.models.word2vec import Word2Vec
from konlpy.tag import Okt

# %%
#네이버 영화 리뷰 크롤링 데이터 다운
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings.txt", filename="ratings.txt")
reviews = pd.read_table('ratings.txt')
display(reviews)
# Out:
#               id                                           document  label
# 0        8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1        8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2        4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1
# 3        9251303  와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런...      1
# 4       10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.      1
# ...          ...                                                ...    ...
# 199995   8963373                                     포켓 몬스터 짜가 ㅡㅡ;;      0
# 199996   3302770                                              쓰.레.기      0
# 199997   5458175                  완전 사이코영화. 마지막은 더욱더 이 영화의질을 떨어트린다.      0
# 199998   6908648                왜난 재미없었지 ㅠㅠ 라따뚜이 보고나서 스머프 봐서 그런가 ㅋㅋ      0
# 199999   8548411                                    포풍저그가나가신다영차영차영차      0
#
# [200000 rows x 3 columns]

# %%
# 빠른 토큰화를 위해 데이터셋 크기를 절반으로 줄여주겠습니다
reviews = reviews.sample(n=100000,axis = 0,random_state = 100)
reviews
# Out:
#               id                                           document  label
# 180481  10066608                9점대 영화는 아니고 7점 정도 될 영화라 생각하기에 평점 조절      0
# 8971     7458638                                          잔 모로의 마력!      1
# 77027    9764118                                    왜요 이영화가 뭔 죄가있다고      1
# 21656    9792714  ㅋㅋ지금 롤러코스터보는데ㅋㅋ땅콩 나오고 욕설 나오고 뭔가 시기가 지금 나왔으면 재미...      1
# 58303    9769907                         버지니아가 데이빗과 클레어를 자유롭게 해주었다.      1
# ...          ...                                                ...    ...
# 76483     274375                     "유산"을 쉽게 생각하는 우리사회사람들을 지적하는 영화      1
# 76413    2415894                    정말 동화속이야기 왠지 상상하게된달까? 재밌게 보았씁니다      1
# 196175   4753200                       흠................ 이건 진짜 아니야!      0
# 160592   7416398                                      느와르에 먹칠을 해주었네      0
# 171793   5468292                                          너무 썰렁한 영화      0
#
# [100000 rows x 3 columns]

# %%
print('결측치 갯수 확인 \n',reviews.isnull().sum())
# Out:
# 결측치 갯수 확인
#  id          0
# document    3
# label       0
# dtype: int64

# %%
reviews = reviews.dropna(how = 'any')
print('결측치 갯수 확인 \n',reviews.isnull().sum())
# Out:
# 결측치 갯수 확인
#  id          0
# document    0
# label       0
# dtype: int64

# %%
print(len(reviews))
# Out:
# 99997

# %%
# 정규 표현식을 통해 한글 외의 문자를 제거해줍니다
reviews['document'] = reviews['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
display(reviews)
# Out:
# C:\Users\sjkan\AppData\Local\Temp\ipykernel_17796\3194670001.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   reviews['document'] = reviews['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# C:\Users\sjkan\AppData\Local\Temp\ipykernel_17796\3194670001.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['document'] = reviews['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
#               id                                           document  label
# 180481  10066608                  점대 영화는 아니고 점 정도 될 영화라 생각하기에 평점 조절      0
# 8971     7458638                                           잔 모로의 마력      1
# 77027    9764118                                    왜요 이영화가 뭔 죄가있다고      1
# 21656    9792714  ㅋㅋ지금 롤러코스터보는데ㅋㅋ땅콩 나오고 욕설 나오고 뭔가 시기가 지금 나왔으면 재미...      1
# 58303    9769907                          버지니아가 데이빗과 클레어를 자유롭게 해주었다      1
# ...          ...                                                ...    ...
# 76483     274375                       유산을 쉽게 생각하는 우리사회사람들을 지적하는 영화      1
# 76413    2415894                     정말 동화속이야기 왠지 상상하게된달까 재밌게 보았씁니다      1
# 196175   4753200                                        흠 이건 진짜 아니야      0
# 160592   7416398                                      느와르에 먹칠을 해주었네      0
# 171793   5468292                                          너무 썰렁한 영화      0
#
# [99997 rows x 3 columns]

# %%
from tqdm import tqdm

stopwords = []

# 형태소 분석기 OKT를 사용한 토큰화 작업 (6분 정도 걸려요!)
okt = Okt()

tokenized_data = []
for sentence in tqdm(reviews['document']):
    tokenized_sentence = okt.morphs(sentence, stem=True)
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    tokenized_data.append(stopwords_removed_sentence)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 99997/99997 [16:57<00:00, 98.29it/s]

# %%
import collections

# %%
list=[]
for i in range(len(tokenized_data)):
    for j in tokenized_data[i]:
        list.append(j)

# %%
counts = collections.Counter(list)
print(counts)
# Out:
# Counter({'이': 37280, '영화': 34176, '보다': 27479, '하다': 27215, '의': 20630, '에': 18341, '가': 17970, '을': 15494, '도': 13948, '들': 12120, '는': 11348, '를': 10801, '은': 10638, '없다': 10358, '이다': 8870, '있다': 8198, '좋다': 7994, '너무': 7579, '다': 6793, '정말': 6529, '한': 6463, '재밌다': 5998, '되다': 5957, '만': 5901, '적': 5815, '진짜': 5674, '같다': 5591, '로': 5281, '으로': 5248, '아니다': 5162, '않다': 5157, '점': 5058, '에서': 4637, '만들다': 4294, '나오다': 4288, '연기': 4241, '평점': 4222, '과': 4202, '것': 4186, '최고': 4052, '내': 3969, '그': 3775, '나': 3737, '안': 3707, '인': 3687, '생각': 3543, '스토리': 3539, '못': 3522, '왜': 3428, '드라마': 3360, '게': 3324, '감동': 3248, '사람': 3189, '보고': 3103, '아깝다': 3051, '말': 3027, '고': 3022, '이렇다': 3020, '때': 2940, '더': 2885, 'ㅋㅋ': 2833, '배우': 2804, '와': 2802, '아': 2786, '감독': 2785, '그냥': 2767, '재미있다': 2721, '거': 2682, '요': 2615, '내용': 2583, '까지': 2576, '재미': 2573, '주다': 2550, '시간': 2540, '중': 2530, '재미없다': 2480, '뭐': 2477, '좀': 2466, '자다': 2443, '지루하다': 2443, '하고': 2394, '쓰레기': 2349, '수': 2249, '네': 2247, '가다': 2163, '들다': 2140, '그렇다': 2116, '모르다': 2113, '싶다': 2022, '지': 2015, '사랑': 2007, '작품': 1998, '볼': 1957, '알다': 1954, '하나': 1903, '다시': 1875, '마지막': 1847, '잘': 1844, '이건': 1742, '정도': 1737, '오다': 1709, '저': 1698, '많다': 1672, 'ㅠㅠ': 1669, '완전': 1668, '처음': 1659, 'ㅋ': 1650, 'ㅋㅋㅋ': 1629, '주인공': 1586, '장면': 1565, '걸': 1564, '이렇게': 1558, '액션': 1552, '안되다': 1536, '차다': 1517, '나다': 1512, '하': 1506, '지금': 1498, '개': 1480, '이야기': 1476, '돈': 1451, '최악': 1434, '별로': 1417, '느낌': 1400, '넘다': 1386, '연출': 1380, 'ㅡㅡ': 1376, '듯': 1373, '임': 1362, '년': 1357, '명작': 1356, '좋아하다': 1355, '인데': 1352, '끝': 1345, '그리고': 1338, '라': 1330, '기': 1322, '받다': 1302, '이해': 1300, '역시': 1297, '별': 1297, '많이': 1290, '난': 1289, '면': 1250, '분': 1247, '라고': 1239, '이영화': 1228, '남다': 1227, '괜찮다': 1226, '이런': 1224, '부터': 1220, '서': 1199, '때문': 1195, '버리다': 1181, '여자': 1180, '또': 1171, '성': 1165, '느끼다': 1154, '꼭': 1134, '이나': 1129, '해주다': 1118, '먹다': 1115, '보기': 1112, '아름답다': 1103, '일': 1102, '전': 1097, '여': 1093, '에게': 1081, '인생': 1078, '두': 1072, '편': 1069, '짱': 1068, '기억': 1066, '결말': 1062, '야': 1057, '이고': 1052, '엔': 1052, '마음': 1046, 'ㅎㅎ': 1044, '대': 1034, '무슨': 1025, '뻔하다': 1024, '애': 1024, '수준': 1011, '끄다': 1007, '소재': 999, '랑': 996, '재다': 994, '보여주다': 987, '아쉽다': 985, '님': 977, '무섭다': 976, '영': 975, '없이': 971, '어떻다': 968, '어리다': 967, '씨': 959, '속': 945, '현실': 942, '매력': 942, '반전': 942, '슬프다': 938, '맞다': 929, '본': 928, '전개': 928, '웃기다': 924, '가장': 921, '낮다': 914, '급': 911, '말다': 910, '한번': 903, '라는': 901, '제': 900, '죽다': 898, '끝나다': 895, '남자': 891, '되어다': 889, '한국': 877, '멋지다': 872, '알': 869, '가슴': 868, '뿐': 866, '다른': 863, '높다': 862, '아이': 850, '니': 849, '음악': 848, '솔직하다': 845, '유치하다': 837, '쓰다': 836, '번': 833, '크다': 832, '냐': 809, '늘다': 807, '줄': 806, '인간': 805, '원작': 804, '눈물': 804, '추천': 803, '화': 796, '함': 795, '내다': 784, '우리': 783, '지만': 781, '눈': 770, '자체': 769, '살다': 766, '모든': 762, '찍다': 759, '인지': 752, '뭔가': 735, '하지만': 734, '보이다': 730, '야하다': 727, '코미디': 725, '이쁘다': 722, '처럼': 718, '허다': 718, '인가': 716, '그래도': 716, '캐릭터': 715, '짜증나다': 712, '대한': 712, 'ㅋㅋㅋㅋ': 705, '이네': 704, '모두': 696, '표현': 692, '대박': 691, '중간': 686, 'ㅠ': 686, '이상': 685, '치다': 684, '돼다': 684, '건지다': 683, '연기력': 683, '미치다': 682, '시리즈': 681, '움': 681, '전혀': 681, '아주': 677, '기대하다': 672, '모습': 671, '지다': 663, '공감': 663, '시키다': 661, '제목': 661, '기대': 654, '근데': 652, '에는': 652, '굿': 651, '작': 649, '여운': 647, '개봉': 644, '영상': 641, '자': 641, '진심': 640, '일본': 638, '보지': 638, '부분': 637, 'ㅜㅜ': 633, '실망': 628, '계속': 627, '이제': 627, '가족': 623, '이랑': 621, '귀엽다': 621, '믿다': 619, '기분': 610, '내내': 605, '대단하다': 604, '뭔': 601, '짜다': 599, '용': 597, '연': 597, '건': 593, '밖에': 593, '이라': 589, '빠지다': 589, '잔잔하다': 585, '후': 585, '작가': 580, '점도': 578, '요즘': 578, '몰입': 577, 'ㅎ': 576, '개인': 573, '감': 573, '떨어지다': 572, '이라는': 571, '대사': 568, '잼': 568, '공포': 567, '이지': 559, '시': 557, '위': 554, '이상하다': 545, '애니': 540, '조금': 540, '웃다': 539, '극장': 537, '긴장감': 536, '딱': 534, '한테': 531, '점수': 530, '깊다': 529, '스릴러': 528, '오랜': 528,  ...

# %%
from tqdm import tqdm

'''
##### TODO 1 #####

분석에 무관할 것 같은 불용어들을 직접 선정해 넣어주세요
저는 주로 데이터 도메인과 너무 직접적인 단어(ex.영화)를 넣거나,
토큰화 찍어보고 쓱쓱 내려본 다음에 눈에 거슬리는 것들을 때려박습니다.
이건 연습이니 아무거나 넣으셔도 상관 없습니다!
'''
stopwords = ['이','영화','하다','의','에','가','을','도','들','는','를','은','이다','다','로','으로','에서','과','것','그','나']

# 형태소 분석기 OKT를 사용한 토큰화 작업 (6분 정도 걸려요!)
okt = Okt()

tokenized_data = []
for sentence in tqdm(reviews['document']):
    tokenized_sentence = okt.morphs(sentence, stem=True)
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    tokenized_data.append(stopwords_removed_sentence)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 99997/99997 [28:33<00:00, 58.37it/s]

# %%
# 리뷰 길이 분포 확인
print('리뷰의 최대 길이 :',max(len(review) for review in tokenized_data))
print('리뷰의 평균 길이 :',sum(map(len, tokenized_data))/len(tokenized_data))
plt.hist([len(review) for review in tokenized_data], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 69
# 리뷰의 평균 길이 : 9.999529985899578

# %%
from gensim.models import Word2Vec

'''
model = Word2Vec(data,         # 리스트 형태의 데이터
                 sg=1,         # 0: CBOW, 1: Skip-gram
                 size=100,     # 벡터 크기
                 window=3,     # 윈도우 크기
                 min_count=3,  # 사용할 단어의 최소 빈도(3회 이하 단어는 무시)
                 workers=4)    # 동시에 처리할 작업 수(코어 수와 비슷하게 설정)
'''

model = Word2Vec(sentences = tokenized_data, window = 5, min_count = 5, workers = 4, sg = 0)

# %%
# 앞의 숫자는 임베딩 된 단어의 갯수, 뒤의 숫자는 각 단어벡터의 크기입니다

model.wv.vectors.shape
# Out:
# (11410, 100)

# %%
'''
##### TODO 2 #####
model.wv.most_similar(단어)는 argument로 들어간 단어와 가장 유사한 단어를 순서대로 보여줍니다.
print(model.wv.most_similar("")) 에 적당한 인자를 넣어 해당 단어와 가장 유사한 단어를 확인해보세요.
좋아하는 영화배우나 장르를 해도 좋고, 꿀잼 노잼 등과 같은 평가와 관련된 단어도 좋습니다.
'''
print(model.wv.most_similar("정우성"))
# Out:
# [('엄정화', 0.9591209888458252), ('송강호', 0.9515910148620605), ('전도연', 0.9497564435005188), ('안성기', 0.949378490447998), ('서인국', 0.935698926448822), ('박중훈', 0.9344091415405273), ('설경구', 0.9326443672180176), ('황정민', 0.9324947595596313), ('이연희', 0.9324744939804077), ('알파', 0.9266542792320251)]
